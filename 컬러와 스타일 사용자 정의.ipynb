# %% [markdown]
# ### 분산형 플롯용 사용자 정의 컬러 사용
# 색깔을 정의하고 싶다. → color, edgecolor 파라미터를 사용하라.

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.random.standard_normal((100,2))
A += np.array((-1,-1))

B = np.random.standard_normal((100,2))
B += np.array((1, 1))

plt.scatter(A[:,0], A[:,1], color = '0')   # 수치는 명암을 따지는 정도 높을수록 하얘진다. 
plt.scatter(B[:,0], B[:,1], color = '0.75') 
plt.show()

# %%
### edgecolor 파라미터로 가장자리 컬러도 제어할 수 있다.
import numpy as np 
import matplotlib.pyplot as plt

data = np.random.standard_normal((100, 2))

plt.scatter(data[:,0], data[:,1], color='r', edgecolor='b')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

data = np.random.standard_normal((100, 2))

plt.scatter(data[:,0], data[:,1], color='1', edgecolor='0')   # 겉에만 검은 색으로 했다.
plt.show()

# %% [markdown]
# ### 막대 차트용 사용자 정의 컬러 사용
# 막대의 색깔을 정의하고 싶다. → color, edgecolor 파라미터를 사용한다.

# %%
import numpy as np
import matplotlib.pyplot as plt

women_pop = np.array([5, 30, 45, 22])
men_pop = np.array([5, 25, 50, 20])

X = np.arange(4)
plt.barh(X, women_pop, color = '.25')
plt.barh(X, -men_pop, color = '.75')

plt.show()

# %% [markdown]
# ### 원형 차트용 사용자 정의 컬러 사용
# 색깔을 정의하고 싶다. → colors 파라미터를 이용해 컬러 리스트를 받는다.
# - 컬러 리스트는 값 입력 리스트보다 많은 요소를 가질 수 없다.
# - 컬러 리스트의 값이 부족하면 비교적 단순한 원형이 된다.

# %%
import numpy as np
import matplotlib.pyplot as plt

values = np.random.rand(8)
color_set = ('r', 'b', 'w', 'darkorange')

plt.pie(values, colors = color_set)
plt.show()
